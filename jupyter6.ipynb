# %%
import nltk
from nltk.stem.porter import *
pstemmer = PorterStemmer()

words = ['consolingly','racing']

for word in words:
    print(word + '---->' + pstemmer.stem(word))
# Out:
# consolingly---->consolingli
# racing---->race

# %%
from nltk.stem.snowball import SnowballStemmer

sstemmer = SnowballStemmer(language='english')

print('Porter2 Stemmer')

for word in words:
    print(word + '------>' + sstemmer.stem(word))
# Out:
# Porter2 Stemmer
# consolingly------>consol
# racing------>race

# %%
phrase = "I am meeting him tomorrow at the meeting"
for word in phrase.split():
    print(word + ' ----> ' + pstemmer.stem(word))
# Out:
# I ----> i
# am ----> am
# meeting ----> meet
# him ----> him
# tomorrow ----> tomorrow
# at ----> at
# the ----> the
# meeting ----> meet

# %%
#snowball stemmer

for word in phrase.split():
    print(word + ' ----> ' + sstemmer.stem(word))
# Out:
# I ----> i
# am ----> am
# meeting ----> meet
# him ----> him
# tomorrow ----> tomorrow
# at ----> at
# the ----> the
# meeting ----> meet

# %%
phrase = "I am currently pursuing BTech(IT) in LICET"
for word in phrase.split():
    print(word + ' ------> ' + sstemmer.stem(word))
# Out:
# I ------> i
# am ------> am
# currently ------> current
# pursuing ------> pursu
# BTech(IT) ------> btech(it)
# in ------> in
# LICET ------> licet
