# %%
import pandas as pd
import numpy as np
df = pd.read_csv("amazonreviews.tsv",sep='\t')
df.head()
# Out:
#   label                                             review
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...

# %%
df['label'].value_counts()
# Out:
# neg    5097
# pos    4903
# Name: label, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['label'].value_counts()
# Out:
# neg    5097
# pos    4903
# Name: label, dtype: int64

# %%
blanks = []
for i,lb,rv in df.itertuples():
    if(type(rv)==str):
        if(rv.isspace()):
            blanks.append(i)

df.drop(blanks,inplace=True)
df['label'].value_counts()
# Out:
# neg    5097
# pos    4903
# Name: label, dtype: int64

# %%
import pip
pip.main(['install','--user','--only-binary=All','tensorflow'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp39-cp39-win_amd64.whl (331.7 MB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (2.0.2)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.78.1-cp39-cp39-win_amd64.whl (4.8 MB)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (25.12.19)
# Collecting google_pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (18.1.1)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (2.28.1)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (6.33.5)
# Collecting h5py>=3.11.0
#   Using cached h5py-3.14.0-cp39-cp39-win_amd64.whl (2.9 MB)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (3.4.0)
# Collecting keras>=3.10.0
#   Using cached keras-3.10.0-py3-none-any.whl (1.4 MB)
# Collecting ml_dtypes<1.0.0,>=0.5.1
#   Using cached ml_dtypes-0.5.4-cp39-cp39-win_amd64.whl (210 kB)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (63.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (3.1.0)
# Collecting tensorboard~=2.20.0
#   Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: optree in c:\users\24it005\appdata\roaming\python\python39\site-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: rich in c:\users\24it005\appdata\roaming\python\python39\site-packages (from keras>=3.10.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\users\24it005\appdata\roaming\python\python39\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.11)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.3.4)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (9.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\24it005\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Installing collected packages: ml_dtypes, h5py, grpcio, google_pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow

# %%
print("hello")
# Out:
# hello
