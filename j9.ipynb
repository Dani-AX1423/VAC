# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp(u"The Quick brown fox jumper over the lazy dog's back.")
print(doc.text)
# Out:
# The Quick brown fox jumper over the lazy dog's back.

# %%
#print(doc[4].text,doc[4].pos_,doc[4],tag)

doc = nlp(u"I read books on NLP")
r = doc[1]
print(f'{r.text:>{10}} {r.pos_:{8}} {r.tag_:{6}} {spacy.explain(r.tag_):{10}}')
# Out:
#       read VERB     VBP    verb, non-3rd person singular present

# %%
depcounts = doc.count_by(spacy.attrs.DEP)
for k,v in sorted(depcounts.items()):
    print(f'{k}.{doc.vocab[k].text:{4}}:{v}')
# Out:
# 416.dobj:1
# 429.nsubj:1
# 439.pobj:1
# 443.prep:1
# 8206900633647566924.ROOT:1

# %%
from spacy import displacy

# %%
doc = nlp(u"The quick brown fox juped over the lazy dog's back")

for token in doc:
    print(f'{token.text:{10}} {token.pos_:{8}} {token.dep_:{8}} {spacy.explain(token.dep_)}')
# Out:
# The        DET      det      determiner
# quick      ADJ      amod     adjectival modifier
# brown      ADJ      amod     adjectival modifier
# fox        NOUN     nsubj    nominal subject
# juped      VERB     ROOT     root
# over       ADP      prep     prepositional modifier
# the        DET      det      determiner
# lazy       ADJ      amod     adjectival modifier
# dog        NOUN     pobj     object of preposition
# 's         PART     case     case marking
# back       NOUN     advmod   adverbial modifier

# %%
doc2 = nlp(u"This is a sentence.This is another possibily longer sentence.")
spans = list(doc2.sents)
opts = {'distance':110,'compact':'False','color':'yellow','bg':''}

# %%
def showents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text+'-'+ent.label_+'-'+str(spacy.explain(ent.label_)))
    else:
        print("No named entities found")

# %%
doc3 = nlp(u"May I go to Washington,DC next May to see the washington Monuments?")
showents(doc3)
# Out:
# Washington,DC-GPE-Countries, cities, states
# next May-DATE-Absolute or relative dates or periods
# the washington Monuments-ORG-Companies, agencies, institutions, etc.

# %%
doc = nlp(U"Tesla to build a U.K. factory for $6 million")
showents(doc)
# Out:
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc = nlp(U"Tesla to build a U.K. factory for $6 million")
org = doc.vocab.strings[U'org']
newent = spacy.tokens.span.Span(doc,0,1,label=org)
doc.ents = list(doc.ents) + [newent]
 
showents(doc)
# Out:
# Tesla-org-None
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc = nlp(U"Our company plans to introduce a new vacuum cleaner."U"If successfull, the vacuum cleaner will be our first product.")

phraselist = ['vaacuum cleaner','vacuum_cleaner'] 
phrasepatterns = [nlp(text) for text in phraselist]
matcher.add('newproduct',None,*phrasepatterns)
matches = matcher(doc)
print(matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11520\789450847.py in <module>
#       3 phraselist = ['vaacuum cleaner','vacuum_cleaner']
#       4 phrasepatterns = [nlp(text) for text in phraselist]
# ----> 5 matcher.add('newproduct',None,*phrasepatterns)
#       6 matches = matcher(doc)
#       7 print(matches)
#
# NameError: name 'matcher' is not defined
