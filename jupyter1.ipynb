# %%
import pip
# Installing both spacy and nltk
pip.main(['install', '--user', 'spacy', 'nltk'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#   Using cached spacy-3.8.11.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [98 lines of output]
# ...
#         Using cached setuptools-82.0.0-py3-none-any.whl (1.0 MB)
# ...
#         Using cached cython-3.2.4-cp39-cp39-win_amd64.whl (2.8 MB)
# ...
#         Using cached cymem-2.0.13-cp39-cp39-win_amd64.whl (40 kB)
# ...
#         Using cached preshed-3.0.12-cp39-cp39-win_amd64.whl (118 kB)
# ...

# %%
library = [('Author', 'Topic','Pages'),('Dani','rafting', 601)]
for book in library:
    print(f'{book[0]:{10}} {book[1]:{8}} {book[2]:{5}}')
# Out:
# Author     Topic    Pages
# Dani       rafting    601

# %%
import pip
pip.main(['install', '--user', '--only-binary=:all:', 'spacy==3.7.5', 'nltk'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ...
# Output()
# ...

# %%
print("jeggrg")
# Out:
# jeggrg

# %%
import spacy

# %%
import pip
pip.main(['install', '--user', 'https://github.com'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   ERROR: Cannot unpack file C:\Users\24IT005\AppData\Local\Temp\pip-unpack-2grsq909\github.com (downloaded from C:\Users\24IT005\AppData\Local\Temp\pip-req-build-w54iq0w1, content-type: text/html; charset=utf-8); cannot detect archive format
# ERROR: Cannot determine archive format of C:\Users\24IT005\AppData\Local\Temp\pip-req-build-w54iq0w1
# 1

# %%
import pip
# This tells spaCy to find the model by its official name
pip.main(['install', '--user', 'en_core_web_sm'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ERROR: Could not find a version that satisfies the requirement en_core_web_sm (from versions: none)
# ERROR: No matching distribution found for en_core_web_sm
# 1

# %%
import pip
model_url = "https://github.com"
pip.main(['install', '--user', model_url])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   ERROR: Cannot unpack file C:\Users\24IT005\AppData\Local\Temp\pip-unpack-es42nooj\github.com (downloaded from C:\Users\24IT005\AppData\Local\Temp\pip-req-build-uej4mezt, content-type: text/html; charset=utf-8); cannot detect archive format
# ERROR: Cannot determine archive format of C:\Users\24IT005\AppData\Local\Temp\pip-req-build-uej4mezt
# 1

# %%
import spacy
import nltk

# Load the model
nlp = spacy.load("en_core_web_sm")

# Test it
doc = nlp("Success! College computer restrictions bypassed.")
for token in doc:
    print(f"{token.text} --> {token.pos_}")

# Test NLTK
print("\nNLTK version:", nltk.__version__)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5056\862262810.py in <module>
#       3
#       4 # Load the model
# ----> 5 nlp = spacy.load("en_core_web_sm")
#       6
#       7 # Test it
#
# ~\AppData\Roaming\Python\Python39\site-packages\spacy\__init__.py in load(name, vocab, disable, enable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#
# ~\AppData\Roaming\Python\Python39\site-packages\spacy\util.py in load_model(name, vocab, disable, enable, exclude, config)
#     470     if name in OLD_MODEL_SHORTCUTS:
#     471         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472     raise IOError(Errors.E050.format(name=name))
#     473
#     474
#
# ...

# %%
import pip
model_url = "https://github.com"
pip.main(['install', '--user', model_url])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#   ERROR: Cannot unpack file C:\Users\24IT005\AppData\Local\Temp\pip-unpack-rk860bqi\github.com (downloaded from C:\Users\24IT005\AppData\Local\Temp\pip-req-build-3cq9h0z7, content-type: text/html; charset=utf-8); cannot detect archive format
# ERROR: Cannot determine archive format of C:\Users\24IT005\AppData\Local\Temp\pip-req-build-3cq9h0z7
# 1

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import en_core_web_sm

# Load using the module itself
nlp = en_core_web_sm.load()

doc = nlp("Success! The model is finally working.")
print([(t.text, t.pos_) for t in doc])
# Out:
# [('Success', 'NOUN'), ('!', 'PUNCT'), ('The', 'DET'), ('model', 'NOUN'), ('is', 'AUX'), ('finally', 'ADV'), ('working', 'VERB'), ('.', 'PUNCT')]

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\24IT005\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\24IT005\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\24IT005\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\24IT005\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\24IT005\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# ...

# %%
from datetime import datetime
today = datetime(year=2018, month=1, day=27)
print(f'{today:%B %d, %Y}')
# Out:
# January 27, 2018

# %%
# %%writefile loyola.txt
# Hello, this is a quick test file.
# This is the second line of the file.
# Out:
# Writing loyola.txt

# %%
myfile = open("loyola.txt")
myfile.read()
# Out:
# 'Hello, this is a quick test file.\nThis is the second line of the file.\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.seek(0)
#myfile.read()
myfile.readlines()
myfile.close()
# Out:
# ['Hello, this is a quick test file.\n',
#  'This is the second line of the file.\n']

# %%
myfileW = open("loyola.txt","w+")
myfileW.write("This is a new line written using write()\n")
myfileW.close()
myfileR = open("loyola.txt","r+")
myfileR.seek(0)
print("file content:")
print(myfileR.read())


myfileR.close()
# Out:
# file content:
# This is a new line written using write()

# %%
myfileA = open("loyola.txt","a+")
myfileA.write("This line is being appended to Loyola.txt")

myfileA.close()

# %%
with open("loyola.txt","r") as txt:
    lines=txt.readlines()
    for l in lines:
        for c in l:
            print(c)
        print(l)
# Out:
# T
# h
# i
# s
#
# i
# s
#
# a
#
# n
# e
# w
#
# l
# i
# n
# e
#
# w
# r
# i
# t
# t
# e
# n
#
# u
# s
# i
# n
# g
#
# w
# r
# i
# t
# e
# (
# )
#
#
# This is a new line written using write()
#
# T
# h
# i
# s
#
# l
# i
# n
# e
#
# i
# s
#
# b
# e
# i
# n
# g
#
# a
# p
# p
# e
# n
# d
# e
# d
#
# t
# o
#
# L
# o
# y
# o
# l
# a
# .
# t
# x
# t
# This line is being appended to Loyola.txt

# %%
import pip

pip.main(['install', '--user', '--only-binary=:all:', 'PyPDF2'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#   Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# ...
# 0

# %%
import PyPDF2 as pr
f = open("Business_Proposal.pdf",'rb')
pdfR = pr.PdfReader(f)
len(pdfR.pages)
p1text = pdfR.pages[0].extract_text()
print(p1text)
# Out:
# WARNING: incorrect startxref pointer(1)
# San José State University Writing Center www.sjsu.edu/writingcenter  Written by Andrew Davis
# ...
