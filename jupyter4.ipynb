# %%
import spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
mystring = '"we\'re moving to L.A!"'
doc = nlp(mystring)


for token in doc:
    print(token.text,end='|')
# Out:
# "|we|'re|moving|to|L.A|!|"|

# %%
doc5 = nlp(u"It is better to give than to receive")
doc5[2]
# Out:
# better

# %%
doc5[2:5]
# Out:
# better to give

# %%
doc5[-4:]
#doc[3] = doc5[3]
# Out:
# give than to receive

# %%
doc8 = nlp(u"Apple to build a Hong Kong factory for $6 million")
for token in doc8:
    print(token.text,end ='|')
print('\n\n\n-----\n', doc8.ents)

for ent in doc8.ents:
    print(ent.text,"-------", ent.label_, "-------",str(spacy.explain(ent.label_)))
# Out:
# Apple|to|build|a|Hong|Kong|factory|for|$|6|million|
#
#
# -----
#  (Apple, Hong Kong, $6 million)
# Apple ------- ORG ------- Companies, agencies, institutions, etc.
# Hong Kong ------- GPE ------- Countries, cities, states
# $6 million ------- MONEY ------- Monetary values, including unit

# %%
for chunk in doc8.noun_chunks:
    print(chunk.text)
# Out:
# Apple
# a Hong Kong factory

# %%
doc11 = nlp(u"He was a one-eyed, one-horned, flying, purple people-eater.")
for chunk in doc11.noun_chunks:
    print(chunk.text)
# Out:
# He
# a one-eyed, one-horned, flying, purple people-eater

# %%
from spacy import displacy
displacy.render(doc11,style='dep',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6f041ab407ab4602957ddc178834f74b-0" class="displacy" width="1260" height="522.0" direction="ltr" style="max-width: none; height: 522.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">one-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">eyed,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">one-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">horned,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">flying,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">purple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">people-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="432.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">eater.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-0" stroke-width="2px" d="M70,387.0 C70,332.0 130.0,332.0 130.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,389.0 L62,377.0 78,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-1" stroke-width="2px" d="M290,387.0 C290,57.0 1145.0,57.0 1145.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,389.0 L282,377.0 298,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-2" stroke-width="2px" d="M400,387.0 C400,332.0 460.0,332.0 460.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,389.0 L392,377.0 408,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-3" stroke-width="2px" d="M510,387.0 C510,112.0 1140.0,112.0 1140.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,389.0 L502,377.0 518,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-4" stroke-width="2px" d="M620,387.0 C620,332.0 680.0,332.0 680.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,389.0 L612,377.0 628,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-5" stroke-width="2px" d="M730,387.0 C730,167.0 1135.0,167.0 1135.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,389.0 L722,377.0 738,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-6" stroke-width="2px" d="M840,387.0 C840,222.0 1130.0,222.0 1130.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,389.0 L832,377.0 848,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-7" stroke-width="2px" d="M950,387.0 C950,277.0 1125.0,277.0 1125.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f041ab407ab4602957ddc178834f74b-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950,389.0 L942,377.0 958,377.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f041ab407ab4602957ddc178834f74b-0-8" stroke-width="2px" d="M1060,387.0 C1060,332.0 1120.0,332.0 1120.0,387.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="

# %%
from spacy import displacy
displacy.render(doc11,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He was a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -eyed,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -horned, flying, purple people-eater.</div></span>
